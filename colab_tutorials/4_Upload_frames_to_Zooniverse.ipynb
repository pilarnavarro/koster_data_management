# %% [markdown]
# <img align="left" src="https://panoptes-uploads.zooniverse.org/project_avatar/86c23ca7-bbaa-4e84-8d8a-876819551431.png" type="image/png" height=100 width=100>
# </img>
# <h1 align="right">Colab KSO Tutorials #4: Upload frames to Zooniverse</h1>
# <h3 align="right">Written by @jannesgg and @vykanton</h3>
# <h5 align="right">Last updated: Jun 3, 2022</h5>

# %% [markdown]
# # Set up and requirements

# %% [markdown]
# ## Install kso_data_management and its requirements

# %%
# Fix issue with panoptes and libmagic
# !apt-get update && apt-get install -y libmagic-dev

# Clone koster_data_management repo
# !git clone --recurse-submodules -b dev https://github.com/ocean-data-factory-sweden/koster_data_management.git
# !pip install -r koster_data_management/requirements.txt

# Restart the session to load the latest packages
exit()

# %% [markdown]
# ### Import Python packages

# %%
# Set the directory of the libraries
import sys, os
from pathlib import Path

# Enables testing changes in utils
# %load_ext autoreload
# %autoreload 2

# Specify the path of the tutorials
os.chdir("koster_data_management/tutorials")
sys.path.append('..')

# Import required modules
import kso_utils.tutorials_utils as t_utils
import kso_utils.t4_utils as t4
import kso_utils.t3_utils as t3
import kso_utils.project_utils as p_utils

print("Packages loaded successfully")
# Out:
# Packages loaded successfully

# %% [markdown]
# ### Choose your project

# %%
project_name = t_utils.choose_project()
# Out:
# Dropdown(description='Project:', options=('Template project', 'Koster_Seafloor_Obs', 'Spyfish_Aotearoa', 'SGU'…

# %%
project = p_utils.find_project(project_name=project_name.value)

# %% [markdown]
# # Setup frame information

# %%
db_info_dict, zoo_project, zoo_info_dict = t4.setup_frame_info(project)
# Out:
# Enter the key id for the aws server··········
# Enter the secret access key for the aws server··········
# db_spyfish_csv/sites_buv_doc.csv: 100%|██████████| 145k/145k [00:01<00:00, 132kB/s]
# db_spyfish_csv/movies_buv_doc.csv: 100%|██████████| 35.1k/35.1k [00:00<00:00, 71.6kB/s]
# db_spyfish_csv/species_buv_doc.csv: 100%|██████████| 7.53k/7.53k [00:00<00:00, 16.2kB/s]
# db_spyfish_csv/surveys_buv_doc.csv: 100%|██████████| 2.92k/2.92k [00:00<00:00, 6.32kB/s]
# db_spyfish_csv/choices_buv.csv: 100%|██████████| 3.58k/3.58k [00:00<00:00, 7.88kB/s]
# Updated sites
# Updated movies
# Updated species
# Enter your Zooniverse user··········
# Enter your Zooniverse password··········
# Retrieving subjects from Zooniverse
# subjects were retrieved successfully
# Retrieving classifications from Zooniverse
# classifications were retrieved successfully
# Retrieving workflows from Zooniverse
# workflows were retrieved successfully
# Updated subjects
# The database has a total of 978 frame subjects and 6253 clip subjects have been updated

# %% [markdown]
# # Retrieve frames

# %% [markdown]
# ## Select the species of interest

# %%
# Specify the species of interest
species_i = t4.choose_species(db_info_dict["db_path"])
# Out:
# SelectMultiple(description='Species', index=(0,), options=('Bait', 'Banded weedfish', 'Banded wrasse', 'Barrac…

# %% [markdown]
# ### Create the frames

# %%
frames_to_upload_df = t4.get_frames(species_names = species_i.value, 
                                    db_path = db_info_dict["db_path"],
                                    zoo_info_dict = zoo_info_dict,
                                    server_dict = db_info_dict,
                                    project = project,
                                    n_frames_subject = 3,
                                    subsample_up_to = 3)
# Out:
# WidgetMaker(children=(IntText(value=0, description='Number of workflows:', style=DescriptionStyle(description_…
# FloatSlider(value=0.8, continuous_update=False, description='Aggregation threshold:', max=1.0, readout_format=…
# IntSlider(value=3, continuous_update=False, description='Min numbers of users:', max=15, min=1, style=SliderSt…
# FileChooser(path='.', filename='', title='HTML(value='<b>Choose location to store frames</b>')', show_hidden='…

# %% [markdown]
# ## List available frames to upload to Zooniverse

# %% [markdown]
# ### Frame modifications

# %%
# Work in progress
frame_modification = t3.clip_modification_widget()
frame_modification
# Out:
# clip_modification_widget(children=(IntText(value=0, description='Number of modifications:', style=DescriptionS…

# %%
frames_to_upload_df
# Out:
# FileChooser(path='.', filename='', title='HTML(value='<b>Choose location to store frames</b>')', show_hidden='…

# %%
# Modify the clips
frames_ready_df = t4.modify_frames(frames_to_upload_df = frames_to_upload_df.df.reset_index(drop=True), 
                                 species_i = species_i.value,
                                 modification_details = frame_modification.checks,
                                 project = project)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-20f905466de9> in <module>
#       1 # Modify the clips
# ----> 2 frames_ready_df = t4.modify_frames(frames_to_upload_df = frames_to_upload_df.df.reset_index(drop=True),
#       3                                  species_i = species_i.value,
#       4                                  modification_details = frame_modification.checks,
#       5                                  project = project)
#
# AttributeError: 'FileChooser' object has no attribute 'df'

# %%
# Review the size of the modified clips
t4.check_frame_size(frame_paths = frames_ready_df["modif_frame_path"].unique())

# %% [markdown]
# ### Preview the frames

# %%
# Compare the original and modified clips
t4.compare_frames(df = frames_ready_df)

# %% [markdown]
# ### Set Zooniverse metadata

# %%
upload_to_zoo = t4.set_zoo_metadata(df = frames_ready_df, species_list = species_i.value,
                                   project = project, db_info_dict = db_info_dict)

#upload_to_zoo = upload_to_zoo.fillna("unknown")

# %% [markdown]
# ### Upload frames to Zooniverse

# %% [markdown]
# You may receive an error message related to file size if clips exceed the recommended limit for Zooniverse uploads. In this case, we recommend shortening the clip length to achieve a suitable filesize.

# %%
t4.upload_frames_to_zooniverse(upload_to_zoo = upload_to_zoo,
                              species_list = species_i.value,
                              db_info_dict = db_info_dict,
                              project = project)
#END
